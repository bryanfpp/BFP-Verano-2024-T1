# %%
import CodeBase15.datos as da
import CodeBase15.fre as fr
import CodeBase15.grafica as gra
import CodeBase15.barras as bar
import CodeBase15.nombre as nom
import CodeBase15.fr as fre
import CodeBase15.frecuancia_acum as acum
import CodeBase15.tabla as tb

# %%
mi_arreglo = [
  'Ramirez','Garcia','Gonzalez','Rodriguez','Perez','Martinez','Garcia','Lopez','Gutierrez',
'Lopez','Rodriguez','Martinez','Rodriguez','Hernandez','Garcia','Hernandez','Lopez',
'Perez','Gonzalez','Martinez','Garcia','Ramirez','Gonzalez','Hernandez','Garcia','Gutierrez',
'Garcia','Rodriguez','Hernandez','Sanchez','Hernandez','Gonzalez','Rodriguez','Sanchez','Hernandez',
'Gonzalez','Gutierrez','Martinez','Gonzalez','Rodriguez','Rodriguez','Martinez','Ramirez',
'Perez','Sanchez','Hernandez','Hernandez','Gonzalez','Garcia','Hernandez','Rodriguez','Lopez',
'Sanchez','Rodriguez','Ramirez','Gonzalez','Lopez','Martinez','Lopez','Garcia','Lopez','Sanchez',
'Martinez','Garcia','Garcia','Hernandez','Garcia','Hernandez','Flores','Perez','Gonzalez','Gonzalez'
,'Lopez','Martinez','Gonzalez','Martinez','Hernandez','Ramirez','Lopez','Sanchez','Ramirez','Gutierrez'
,'Sanchez','Flores','Garcia','Martinez','Garcia','Flores','Perez','Lopez','Hernandez','Martinez','Garcia'
,'Hernandez','Flores','Perez','Gonzalez','Hernandez','Sanchez','Martinez'
]
resultado = da.procesar_cadenas(mi_arreglo)
unique_names = nom.get_unique_names(resultado)
frecuancia = fr.contar_repeticiones_por_cadena(resultado)
frec = fre.fr_abs(frecuancia)
tg = acum.sum_abs(frec)

tb.printTable(["Clase","Frecuencia Absoluta", "Frecuancia relativa","Frecuancia relativa acum"], [unique_names,frecuancia,frec,tg])
bar.crear_diagrama_pastel(unique_names, frecuancia, titulo="Diagrama de Pastel")
# Out:
# | Clase     |   Frecuencia Absoluta |   Frecuancia relativa |   Frecuancia relativa acum |
# |-----------+-----------------------+-----------------------+----------------------------|
# | FLORES    |                     6 |                  0.06 |                       0.06 |
# | GARCIA    |                    14 |                  0.14 |                       0.2  |
# | GONZALEZ  |                    12 |                  0.12 |                       0.32 |
# | GUTIERREZ |                     9 |                  0.09 |                       0.41 |
# | HERNANDEZ |                     6 |                  0.06 |                       0.47 |
# | LOPEZ     |                    12 |                  0.12 |                       0.59 |
# | MARTINEZ  |                    10 |                  0.1  |                       0.69 |
# | PEREZ     |                     4 |                  0.04 |                       0.73 |
# | RAMIREZ   |                    15 |                  0.15 |                       0.88 |
# | RODRIGUEZ |                     8 |                  0.08 |                       0.96 |
# | SANCHEZ   |                     4 |                  0.04 |                       1    |
